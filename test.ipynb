# %%
import pandas as pd

# %%
df = pd.read_parquet("data/fe/standings_train.parquet")

# %%
print(df.shape)
df.head()
# Out:
# (40, 23)
#                    race_id  event_year          event_name Driver  \
# 0  2023_Bahrain Grand Prix        2023  Bahrain Grand Prix    ALB
# 1   2023_Monaco Grand Prix        2023   Monaco Grand Prix    ALB
# 2  2023_Bahrain Grand Prix        2023  Bahrain Grand Prix    ALO
# 3   2023_Monaco Grand Prix        2023   Monaco Grand Prix    ALO
# 4  2023_Bahrain Grand Prix        2023  Bahrain Grand Prix    BOT
#
#   DriverNumber      TeamName  finish_pos  scored_points  grid_pos  \
# 0           23      Williams        10.0              1      15.0
# 1           23      Williams        14.0              0      13.0
# 2           14  Aston Martin         3.0              1       5.0
# 3           14  Aston Martin         2.0              1       2.0
# 4           77    Alfa Romeo         8.0              1      12.0
#
#    quali_gap_s  ...  pos_change  total_overtakes  pit_loss_total_s  \
# 0        1.753  ...         5.0             42.0            86.447
# ...

# %%
df.head(40)
# Out:
#                     race_id  event_year          event_name Driver  \
# 0   2023_Bahrain Grand Prix        2023  Bahrain Grand Prix    ALB
# 1    2023_Monaco Grand Prix        2023   Monaco Grand Prix    ALB
# 2   2023_Bahrain Grand Prix        2023  Bahrain Grand Prix    ALO
# 3    2023_Monaco Grand Prix        2023   Monaco Grand Prix    ALO
# 4   2023_Bahrain Grand Prix        2023  Bahrain Grand Prix    BOT
# 5    2023_Monaco Grand Prix        2023   Monaco Grand Prix    BOT
# 6   2023_Bahrain Grand Prix        2023  Bahrain Grand Prix    DEV
# 7    2023_Monaco Grand Prix        2023   Monaco Grand Prix    DEV
# 8   2023_Bahrain Grand Prix        2023  Bahrain Grand Prix    GAS
# 9    2023_Monaco Grand Prix        2023   Monaco Grand Prix    GAS
# 10  2023_Bahrain Grand Prix        2023  Bahrain Grand Prix    HAM
# 11   2023_Monaco Grand Prix        2023   Monaco Grand Prix    HAM
# 12  2023_Bahrain Grand Prix        2023  Bahrain Grand Prix    HUL
# ...
