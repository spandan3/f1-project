# %%
import pandas as pd

# %%
df = pd.read_parquet("data/fe/standings_train.parquet")

# %%
print(df.shape)
df.head()
# Out:
# (40, 26)
#   DriverNumber Driver      TeamName  event_year          event_name  \
# 0           23    ALB      Williams        2023  Bahrain Grand Prix
# 1           23    ALB      Williams        2023   Monaco Grand Prix
# 2           14    ALO  Aston Martin        2023  Bahrain Grand Prix
# 3           14    ALO  Aston Martin        2023   Monaco Grand Prix
# 4           77    BOT    Alfa Romeo        2023  Bahrain Grand Prix
#
#    finish_pos    Status  quali_pos_final  quali_gap_s  grid_pos  ...  \
# 0        10.0  Finished             15.0        1.753      15.0  ...
# 1        14.0    Lapped             13.0        1.162      13.0  ...
# 2         3.0  Finished              5.0        0.628       5.0  ...
# 3         2.0  Finished              2.0        0.084       2.0  ...
# 4         8.0  Finished             12.0        1.735      12.0  ...
#
#    mean_air_temp  mean_track_temp  rain_any  mean_wind_speed mean_wind_dir  \
# ...

# %%
df.head(40)
# Out:
#    DriverNumber Driver         TeamName  event_year          event_name  \
# 0            23    ALB         Williams        2023  Bahrain Grand Prix
# 1            23    ALB         Williams        2023   Monaco Grand Prix
# 2            14    ALO     Aston Martin        2023  Bahrain Grand Prix
# 3            14    ALO     Aston Martin        2023   Monaco Grand Prix
# 4            77    BOT       Alfa Romeo        2023  Bahrain Grand Prix
# 5            77    BOT       Alfa Romeo        2023   Monaco Grand Prix
# 6            21    DEV       AlphaTauri        2023  Bahrain Grand Prix
# 7            21    DEV       AlphaTauri        2023   Monaco Grand Prix
# 8            10    GAS           Alpine        2023  Bahrain Grand Prix
# 9            10    GAS           Alpine        2023   Monaco Grand Prix
# 10           44    HAM         Mercedes        2023  Bahrain Grand Prix
# 11           44    HAM         Mercedes        2023   Monaco Grand Prix
# ...

# %%
print(df.columns)
# Out:
# Index(['DriverNumber', 'Driver', 'TeamName', 'event_year', 'event_name',
#        'finish_pos', 'Status', 'quali_pos_final', 'quali_gap_s', 'grid_pos',
#        'grid_quali_diff', 'driver_last3_avg_finish', 'team_last3_avg_finish',
#        'pos_change', 'race_id', 'race_total_overtakes', 'driver_overtakes',
#        'driver_times_overtaken', 'driver_net_passes', 'mean_air_temp',
#        'mean_track_temp', 'rain_any', 'mean_wind_speed', 'mean_wind_dir',
#        'is_wet_flag', 'wind_sin', 'wind_cos', 'pit_loss_total_s',
#        'scored_points'],
#       dtype='object')

# %%
print(df[["Driver", "race_id", "driver_last3_avg_finish"]].head(20))
# Out:
#    Driver                  race_id  driver_last3_avg_finish
# 0     ALB  2023_Bahrain Grand Prix                     10.0
# 1     ALB   2023_Monaco Grand Prix                     10.0
# 2     ALO  2023_Bahrain Grand Prix                      3.0
# 3     ALO   2023_Monaco Grand Prix                      3.0
# 4     BOT  2023_Bahrain Grand Prix                      8.0
# 5     BOT   2023_Monaco Grand Prix                      8.0
# 6     DEV  2023_Bahrain Grand Prix                     14.0
# 7     DEV   2023_Monaco Grand Prix                     14.0
# 8     GAS  2023_Bahrain Grand Prix                      9.0
# 9     GAS   2023_Monaco Grand Prix                      9.0
# 10    HAM  2023_Bahrain Grand Prix                      5.0
# 11    HAM   2023_Monaco Grand Prix                      5.0
# 12    HUL  2023_Bahrain Grand Prix                     15.0
# 13    HUL   2023_Monaco Grand Prix                     15.0
# 14    LEC  2023_Bahrain Grand Prix                     19.0
# ...
