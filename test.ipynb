# %%
import pandas as pd

# %%
df = pd.read_parquet("data/fe/standings_train.parquet")

# %%
print(df.shape)
df.head()
# Out:
# (2399, 29)
#                             race_id  event_year                   event_name  \
# 0  2020_70th Anniversary Grand Prix        2020  70th Anniversary Grand Prix
# 1          2020_Austrian Grand Prix        2020          Austrian Grand Prix
# 2          2020_Austrian Grand Prix        2020          Austrian Grand Prix
# 3          2020_Austrian Grand Prix        2020          Austrian Grand Prix
# 4          2020_Austrian Grand Prix        2020          Austrian Grand Prix
#
#   Driver DriverNumber         TeamName  finish_pos  scored_points  grid_pos  \
# 0    ALB           23  Red Bull Racing         5.0              1       9.0
# 1    ALB           23  Red Bull Racing        13.0              0       4.0
# 2    ALB           23  Red Bull Racing        13.0              0       4.0
# 3    ALB           23  Red Bull Racing        13.0              0       4.0
# 4    ALB           23  Red Bull Racing        13.0              0       4.0
#
# ...

# %%
print(df.columns)
# Out:
# Index(['race_id', 'event_year', 'event_name', 'Driver', 'DriverNumber',
#        'TeamName', 'finish_pos', 'scored_points', 'grid_pos', 'quali_gap_s',
#        'grid_quali_diff', 'driver_last3_avg_finish', 'team_last3_avg_finish',
#        'pos_change', 'race_total_overtakes', 'pit_loss_total_s',
#        'mean_air_temp', 'mean_track_temp', 'mean_wind_speed', 'mean_wind_dir',
#        'wind_sin', 'wind_cos', 'is_wet_flag', 'start_compound', 'start_soft',
#        'start_medium', 'start_hard', 'start_inter', 'start_wet'],
#       dtype='object')

# %%
print(df[["Driver","event_year","event_name","start_compound"]].head())
# Out:
#   Driver  event_year                   event_name start_compound
# 0    ALB        2020  70th Anniversary Grand Prix           Soft
# 1    ALB        2020          Austrian Grand Prix           Soft
# 2    ALB        2020          Austrian Grand Prix           Soft
# 3    ALB        2020          Austrian Grand Prix           Soft
# 4    ALB        2020          Austrian Grand Prix           Soft

# %%
df['race_id'].unique()[:30]
# Out:
# array(['2020_70th Anniversary Grand Prix', '2020_Austrian Grand Prix',
#        '2020_Belgian Grand Prix', '2020_British Grand Prix',
#        '2020_Hungarian Grand Prix', '2020_Spanish Grand Prix',
#        '2020_Styrian Grand Prix', '2022_Abu Dhabi Grand Prix',
#        '2022_Australian Grand Prix', '2022_Austrian Grand Prix',
#        '2022_Azerbaijan Grand Prix', '2022_Bahrain Grand Prix',
#        '2022_Belgian Grand Prix', '2022_British Grand Prix',
#        '2022_Canadian Grand Prix', '2022_Dutch Grand Prix',
#        '2022_Emilia Romagna Grand Prix', '2022_French Grand Prix',
#        '2022_Hungarian Grand Prix', '2022_Japanese Grand Prix',
#        '2022_Mexico City Grand Prix', '2022_Miami Grand Prix',
#        '2022_Monaco Grand Prix', '2022_Saudi Arabian Grand Prix',
#        '2022_Singapore Grand Prix', '2022_Spanish Grand Prix',
#        '2022_São Paulo Grand Prix', '2022_United States Grand Prix',
#        '2023_Abu Dhabi Grand Prix', '2023_Australian Grand Prix'],
# ...

# %%
df2025 = pd.read_parquet("data/fe/2025/standings_2025.parquet")

# %%
df2025.head()
print(df2025.shape)
# Out:
# (239, 32)

# %%
df2025.head()
# Out:
#                       race_id  event_year             event_name Driver  \
# 0  2025_Australian Grand Prix        2025  Australian Grand Prix    ALB
# 1    2025_Austrian Grand Prix        2025    Austrian Grand Prix    ALB
# 2     2025_Bahrain Grand Prix        2025     Bahrain Grand Prix    ALB
# 3     2025_Belgian Grand Prix        2025     Belgian Grand Prix    ALB
# 4     2025_British Grand Prix        2025     British Grand Prix    ALB
#
#   DriverNumber  TeamName  finish_pos  scored_points  grid_pos  quali_gap_s  \
# 0           23  Williams         5.0              1       6.0        0.641
# 1           23  Williams        17.0              0      12.0        1.172
# 2           23  Williams        12.0              0      15.0        2.199
# 3           23  Williams         6.0              1       5.0        0.639
# 4           23  Williams         8.0              1      13.0        0.997
#
#    ...  mean_wind_dir  wind_sin  wind_cos  is_wet_flag  start_compound  \
# ...
