# %%
import pandas as pd

# %%
df = pd.read_parquet("data/fe/standings_train.parquet")

# %%
print(df.shape)
df.head()
# Out:
# (40, 16)
#                    race_id Driver DriverNumber      TeamName  finish_pos  \
# 0  2023_Bahrain Grand Prix    ALB           23      Williams        10.0
# 1   2023_Monaco Grand Prix    ALB           23      Williams        14.0
# 2  2023_Bahrain Grand Prix    ALO           14  Aston Martin         3.0
# 3   2023_Monaco Grand Prix    ALO           14  Aston Martin         2.0
# 4  2023_Bahrain Grand Prix    BOT           77    Alfa Romeo         8.0
#
#    relevance  grid_pos  quali_gap_s  driver_last3_avg_finish  \
# 0          0      15.0        1.753                      NaN
# 1          0      13.0        1.162                     10.0
# 2          1       5.0        0.628                      NaN
# 3          2       2.0        0.084                      3.0
# 4          0      12.0        1.735                      NaN
#
#    team_last3_avg_finish  track_overtake_idx  pit_loss_s  is_wet_flag  \
# 0                    NaN                 0.5        22.0            0
# ...

# %%
df.head(40)
# Out:
#                     race_id Driver DriverNumber         TeamName  finish_pos  \
# 0   2023_Bahrain Grand Prix    ALB           23         Williams        10.0
# 1    2023_Monaco Grand Prix    ALB           23         Williams        14.0
# 2   2023_Bahrain Grand Prix    ALO           14     Aston Martin         3.0
# 3    2023_Monaco Grand Prix    ALO           14     Aston Martin         2.0
# 4   2023_Bahrain Grand Prix    BOT           77       Alfa Romeo         8.0
# 5    2023_Monaco Grand Prix    BOT           77       Alfa Romeo        11.0
# 6   2023_Bahrain Grand Prix    DEV           21       AlphaTauri        14.0
# 7    2023_Monaco Grand Prix    DEV           21       AlphaTauri        12.0
# 8   2023_Bahrain Grand Prix    GAS           10           Alpine         9.0
# 9    2023_Monaco Grand Prix    GAS           10           Alpine         7.0
# 10  2023_Bahrain Grand Prix    HAM           44         Mercedes         5.0
# ...
